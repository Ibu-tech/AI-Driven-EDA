# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

# Make sure to escape backslashes and provide the correct encoding if needed
df = pd.read_csv(r"C:\Users\Admin\Documents\DA -Task 2..csv", encoding='ISO-8859-1')

# %%
df
# Out:
#                   VIN  TRANSACTION_ID  \
# 0   3HCFDDE89SH220903           13021
# 1   1HRFFEE8XSZ230636           13028
# 2   1HYKSMRK6SZ000990           13035
# 3   3HCFDFEL3SH241701           13021
# 4   1HRFFHEL1RZ181474           13021
# ..                ...             ...
# 95  1HYKNHRS6MZ221833           13041
# 96  1HYKSSRL4SZ003381           13048
# 97  1HKKNXLS3SZ128369           13044
# 98  1HC4WLE78RF260518           13045
# 99  1HKKNXLS8MZ121378           13041
#
#                                   CORRECTION_VERBATIM  \
# 0                    REPLACED STEERING WHEEL NOW OKAY
# 1   CHECKED - FOUND DTC'S U0229 - U1530 SET IN BCM...
# 2   APPROVED 4.9(OLH) FOR ADDED DIAGNOSTICS WITH T...
# 3                          STEERING WHEEL REPLACEMENT
# 4       REPLACED STEERING MESSAGE NO LONGER DISPLAYED
# ..                                                ...
# 95  REPLACED STEERING WHEEL COMPLETEDLOP 0130 TIME .4
# 96                             replace steering wheel
# ...

# %%
# Column-wise analysis

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 53 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   VIN                            100 non-null    object
#  1   TRANSACTION_ID                 100 non-null    int64
#  2   CORRECTION_VERBATIM            100 non-null    object
#  3   CUSTOMER_VERBATIM              100 non-null    object
#  4   REPAIR_DATE                    100 non-null    object
#  5   CAUSAL_PART_NM                 95 non-null     object
#  6   GLOBAL_LABOR_CODE_DESCRIPTION  100 non-null    object
#  7   PLATFORM                       100 non-null    object
#  8   BODY_STYLE                     100 non-null    object
#  9   VPPC                           100 non-null    object
#  10  PLANT                          99 non-null     object
#  11  BUILD_COUNTRY                  100 non-null    object
# ...

# %%
# Column-wise analysis
column_analysis = df.describe()
column_analysis
# Out:
#        TRANSACTION_ID  DEALER_REGION  REPAIR_AGE  COMPLAINT_CD_CSI  \
# count      100.000000      100.00000  100.000000             100.0
# mean     13036.900000        1.09000   14.940000               0.0
# std         12.028166        0.51434   12.367945               0.0
# min      13021.000000        1.00000    0.000000               0.0
# 25%      13027.750000        1.00000    5.000000               0.0
# 50%      13036.000000        1.00000   12.000000               0.0
# 75%      13041.250000        1.00000   21.000000               0.0
# max      13081.000000        4.00000   50.000000               0.0
#
#        ORD_SELLING_SRC_CD  GLOBAL_LABOR_CODE  CAMPAIGN_NBR  \
# count          100.000000         100.000000           0.0
# mean            24.590000         251.900000           NaN
# std             17.822976         546.451722           NaN
# min             11.000000          20.000000           NaN
# 25%             13.000000         130.000000           NaN
# ...

# %%
df
# Out:
#                   VIN  TRANSACTION_ID  \
# 0   3HCFDDE89SH220903           13021
# 1   1HRFFEE8XSZ230636           13028
# 2   1HYKSMRK6SZ000990           13035
# 3   3HCFDFEL3SH241701           13021
# 4   1HRFFHEL1RZ181474           13021
# ..                ...             ...
# 95  1HYKNHRS6MZ221833           13041
# 96  1HYKSSRL4SZ003381           13048
# 97  1HKKNXLS3SZ128369           13044
# 98  1HC4WLE78RF260518           13045
# 99  1HKKNXLS8MZ121378           13041
#
#                                   CORRECTION_VERBATIM  \
# 0                    REPLACED STEERING WHEEL NOW OKAY
# 1   CHECKED - FOUND DTC'S U0229 - U1530 SET IN BCM...
# 2   APPROVED 4.9(OLH) FOR ADDED DIAGNOSTICS WITH T...
# 3                          STEERING WHEEL REPLACEMENT
# 4       REPLACED STEERING MESSAGE NO LONGER DISPLAYED
# ..                                                ...
# 95  REPLACED STEERING WHEEL COMPLETEDLOP 0130 TIME .4
# 96                             replace steering wheel
# ...

# %%
import pandas as pd



# Initialize a dictionary to store analysis
column_analysis = {}

for column in df.columns:
    # Data Type
    data_type = df[column].dtype
    
    # Unique Values
    unique_values = df[column].nunique()
    
    # Distribution
    distribution = df[column].value_counts()
    
    # Overall Significance
    if data_type == 'object':
        significance = f"The column '{column}' contains categorical data which can be used for grouping and segmentation."
    else:
        significance = f"The column '{column}' contains numerical data which can be used for statistical analysis and modeling."
    
    # Store analysis in the dictionary
    column_analysis[column] = {
        "Data Type": data_type,
        "Unique Values": unique_values,
        "Distribution": distribution.head(),
        "Significance": significance
    }

# Display the analysis
for column, analysis in column_analysis.items():
    print(f"Column: {column}")
    print(f"Data Type: {analysis['Data Type']}")
    print(f"Unique Values: {analysis['Unique Values']}")
    print(f"Distribution: \n{analysis['Distribution']}")
    print(f"Significance: {analysis['Significance']}\n")
# Out:
# Column: VIN
# Data Type: object
# Unique Values: 98
# Distribution:
# VIN
# 3HRS9EED0LH255650    2
# 1HRFFHEL8RZ133325    2
# 3HCFDDE89SH220903    1
# 3HRFFHEL3SH345370    1
# 3HCFDHEL2SH305075    1
# Name: count, dtype: int64
# Significance: The column 'VIN' contains categorical data which can be used for grouping and segmentation.
#
# Column: TRANSACTION_ID
# Data Type: int64
# Unique Values: 32
# Distribution:
# TRANSACTION_ID
# 13025    10
# 13039     8
# 13030     6
# 13034     5
# 13037     5
# Name: count, dtype: int64
# Significance: The column 'TRANSACTION_ID' contains numerical data which can be used for statistical analysis and modeling.
#
# Column: CORRECTION_VERBATIM
# Data Type: object
# Unique Values: 93
# Distribution:
# CORRECTION_VERBATIM
# Replaced steering wheel                                                                 3
# REPLACED STEERING WHEEL                                                                 3
# ...

# %%
# Display initial information about missing values
print("Initial missing values in each column:")
print(df.isnull().sum())
# Out:
# Initial missing values in each column:
# VIN                                0
# TRANSACTION_ID                     0
# CORRECTION_VERBATIM                0
# CUSTOMER_VERBATIM                  0
# REPAIR_DATE                        0
# CAUSAL_PART_NM                     5
# GLOBAL_LABOR_CODE_DESCRIPTION      0
# PLATFORM                           0
# BODY_STYLE                         0
# VPPC                               0
# PLANT                              1
# BUILD_COUNTRY                      0
# LAST_KNOWN_DLR_NAME                0
# LAST_KNOWN_DLR_CITY                0
# REPAIRING_DEALER_CODE              0
# DEALER_NAME                        0
# REPAIR_DLR_CITY                    0
# STATE                              2
# DEALER_REGION                      0
# REPAIR_DLR_POSTAL_CD               2
# REPAIR_AGE                         0
# KM                                 0
# COMPLAINT_CD_CSI                   0
# COMPLAINT_CD                       0
# ...

# %%
 #Handling missing values in numerical columns
import numpy as np
numeric_cols = df.select_dtypes(include=[np.number]).columns
numeric_cols
# Out:
# Index(['TRANSACTION_ID', 'DEALER_REGION', 'REPAIR_AGE', 'COMPLAINT_CD_CSI',
#        'ORD_SELLING_SRC_CD', 'GLOBAL_LABOR_CODE', 'CAMPAIGN_NBR',
#        'TRANSMISSION_SOURCE_PLANT', 'SRC_TXN_ID', 'SRC_VER_NBR',
#        'TRANSACTION_CNTR', 'LAST_KNOWN_DELVRY_TYPE_CD', 'NON_CAUSAL_PART_QTY',
#        'SALES_REGION_CODE', 'Unnamed: 52'],
#       dtype='object')

# %%
# Fill missing values with mean
for col in numeric_cols:
    df[col] = df[col].fillna(df[col].mean())

# %%
# Handling missing values in categorical columns
categorical_cols = df.select_dtypes(include=[object]).columns

# %%
# Fill missing values with mode
for col in categorical_cols:
    df[col] = df[col].fillna(df[col].mode()[0])
    # Convert numerical columns to numeric type (this will turn invalid entries into NaN)
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')

# %%
# Display information after cleaning
#we droped df = df.drop('Unnamed: 52', axis=1)
print("\nAfter data cleaning:")
print(df.isnull().sum())
# Out:
# After data cleaning:
# VIN                                0
# TRANSACTION_ID                     0
# CORRECTION_VERBATIM                0
# CUSTOMER_VERBATIM                  0
# REPAIR_DATE                        0
# CAUSAL_PART_NM                     0
# GLOBAL_LABOR_CODE_DESCRIPTION      0
# PLATFORM                           0
# BODY_STYLE                         0
# VPPC                               0
# PLANT                              0
# BUILD_COUNTRY                      0
# LAST_KNOWN_DLR_NAME                0
# LAST_KNOWN_DLR_CITY                0
# REPAIRING_DEALER_CODE              0
# DEALER_NAME                        0
# REPAIR_DLR_CITY                    0
# STATE                              0
# DEALER_REGION                      0
# REPAIR_DLR_POSTAL_CD               0
# REPAIR_AGE                         0
# KM                                 0
# COMPLAINT_CD_CSI                   0
# COMPLAINT_CD                       0
# VEH_TEST_GRP                       0
# ...

# %%
df.head()
# Out:
#                  VIN  TRANSACTION_ID  \
# 0  3HCFDDE89SH220903           13021
# 1  1HRFFEE8XSZ230636           13028
# 2  1HYKSMRK6SZ000990           13035
# 3  3HCFDFEL3SH241701           13021
# 4  1HRFFHEL1RZ181474           13021
#
#                                  CORRECTION_VERBATIM  \
# 0                   REPLACED STEERING WHEEL NOW OKAY
# 1  CHECKED - FOUND DTC'S U0229 - U1530 SET IN BCM...
# 2  APPROVED 4.9(OLH) FOR ADDED DIAGNOSTICS WITH T...
# 3                         STEERING WHEEL REPLACEMENT
# 4      REPLACED STEERING MESSAGE NO LONGER DISPLAYED
#
#                                    CUSTOMER_VERBATIM REPAIR_DATE  \
# 0                        STEERING WHEEL COMING APART  01-02-2024
# 1         CUSTOMER STATES HEATED STEERING WHEEL INOP  01-03-2024
# 2  OWNER REPORTS: THE SUPER CRUISE BAR ON THE STE...  01-04-2024
# 3  CUSTOMER STATES THE LETTERING AND FINISH ON TH...  01-04-2024
# 4  C/S: CUSTOMER STATES THE SERVICE DRIVER ASSIST...  01-05-2024
#
# ...

# %%
print(df['CAMPAIGN_NBR'].head(10))
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# 6   NaN
# 7   NaN
# 8   NaN
# 9   NaN
# Name: CAMPAIGN_NBR, dtype: float64

# %%
print(df.columns)
# Out:
# Index(['VIN', 'TRANSACTION_ID', 'CORRECTION_VERBATIM', 'CUSTOMER_VERBATIM',
#        'REPAIR_DATE', 'CAUSAL_PART_NM', 'GLOBAL_LABOR_CODE_DESCRIPTION',
#        'PLATFORM', 'BODY_STYLE', 'VPPC', 'PLANT', 'BUILD_COUNTRY',
#        'LAST_KNOWN_DLR_NAME', 'LAST_KNOWN_DLR_CITY', 'REPAIRING_DEALER_CODE',
#        'DEALER_NAME', 'REPAIR_DLR_CITY', 'STATE', 'DEALER_REGION',
#        'REPAIR_DLR_POSTAL_CD', 'REPAIR_AGE', 'KM', 'COMPLAINT_CD_CSI',
#        'COMPLAINT_CD', 'VEH_TEST_GRP', 'COUNTRY_SALE_ISO',
#        'ORD_SELLING_SRC_CD', 'OPTN_FAMLY_CERTIFICATION',
#        'OPTF_FAMLY_EMISSIOF_SYSTEM', 'GLOBAL_LABOR_CODE',
#        'TRANSACTION_CATEGORY', 'CAMPAIGN_NBR', 'REPORTING_COST', 'TOTALCOST',
#        'LBRCOST', 'ENGINE', 'ENGINE_DESC', 'TRANSMISSION', 'TRANSMISSION_DESC',
#        'ENGINE_SOURCE_PLANT', 'ENGINE_TRACE_NBR', 'TRANSMISSION_SOURCE_PLANT',
#        'TRANSMISSION_TRACE_NBR', 'SRC_TXN_ID', 'SRC_VER_NBR',
# ...

# %%
print(df.isnull().sum())
# Out:
# VIN                                0
# TRANSACTION_ID                     0
# CORRECTION_VERBATIM                0
# CUSTOMER_VERBATIM                  0
# REPAIR_DATE                        0
# CAUSAL_PART_NM                     0
# GLOBAL_LABOR_CODE_DESCRIPTION      0
# PLATFORM                           0
# BODY_STYLE                         0
# VPPC                               0
# PLANT                              0
# BUILD_COUNTRY                      0
# LAST_KNOWN_DLR_NAME                0
# LAST_KNOWN_DLR_CITY                0
# REPAIRING_DEALER_CODE              0
# DEALER_NAME                        0
# REPAIR_DLR_CITY                    0
# STATE                              0
# DEALER_REGION                      0
# REPAIR_DLR_POSTAL_CD               0
# REPAIR_AGE                         0
# KM                                 0
# COMPLAINT_CD_CSI                   0
# COMPLAINT_CD                       0
# VEH_TEST_GRP                       0
# ...

# %%
#we droped 
# Drop columns with 100% missing values
df.drop(columns=['CAMPAIGN_NBR', 'Unnamed: 52'], inplace=True)

# %%
print(df.isnull().sum())
# Out:
# VIN                              0
# TRANSACTION_ID                   0
# CORRECTION_VERBATIM              0
# CUSTOMER_VERBATIM                0
# REPAIR_DATE                      0
# CAUSAL_PART_NM                   0
# GLOBAL_LABOR_CODE_DESCRIPTION    0
# PLATFORM                         0
# BODY_STYLE                       0
# VPPC                             0
# PLANT                            0
# BUILD_COUNTRY                    0
# LAST_KNOWN_DLR_NAME              0
# LAST_KNOWN_DLR_CITY              0
# REPAIRING_DEALER_CODE            0
# DEALER_NAME                      0
# REPAIR_DLR_CITY                  0
# STATE                            0
# DEALER_REGION                    0
# REPAIR_DLR_POSTAL_CD             0
# REPAIR_AGE                       0
# KM                               0
# COMPLAINT_CD_CSI                 0
# COMPLAINT_CD                     0
# VEH_TEST_GRP                     0
# COUNTRY_SALE_ISO                 0
# ORD_SELLING_SRC_CD               0
# ...

# %%
#start by converting all categorical column values to lowercase and stripping any leading or trailing whitespaces to ensure consistency.
# Convert categorical columns to lowercase and strip whitespaces
categorical_cols = df.select_dtypes(include=['object']).columns

for col in categorical_cols:
    df[col] = df[col].str.lower().str.strip()

# Display the cleaned categorical columns
print("\nCategorical columns after converting to lowercase and stripping whitespaces:")
print(df[categorical_cols].head())
# Out:
# Categorical columns after converting to lowercase and stripping whitespaces:
#                  VIN                                CORRECTION_VERBATIM  \
# 0  3hcfdde89sh220903                   replaced steering wheel now okay
# 1  1hrffee8xsz230636  checked - found dtc's u0229 - u1530 set in bcm...
# 2  1hyksmrk6sz000990  approved 4.9(olh) for added diagnostics with t...
# 3  3hcfdfel3sh241701                         steering wheel replacement
# 4  1hrffhel1rz181474      replaced steering message no longer displayed
#
#                                    CUSTOMER_VERBATIM REPAIR_DATE  \
# 0                        steering wheel coming apart  01-02-2024
# 1         customer states heated steering wheel inop  01-03-2024
# 2  owner reports: the super cruise bar on the ste...  01-04-2024
# 3  customer states the lettering and finish on th...  01-04-2024
# 4  c/s: customer states the service driver assist...  01-05-2024
#
# ...

# %%
#identifying and correct common typos using a predefined mapping dictionary.  so to  expand this dictionary based on your actual data
# Dictionary for common typos and their corrections
typo_correction = {
    'categroy': 'category',
    'catgory': 'category',
    'vehcile': 'vehicle',
    'vehciel': 'vehicle',
    # Add more corrections as needed
}

# Replace typos with correct values
df.replace(typo_correction, inplace=True)

# Display the cleaned categorical columns after typo correction
print("\nCategorical columns after correcting common typos:")
df[categorical_cols].head()
# Out:
# Categorical columns after correcting common typos:
#                  VIN                                CORRECTION_VERBATIM  \
# 0  3hcfdde89sh220903                   replaced steering wheel now okay
# 1  1hrffee8xsz230636  checked - found dtc's u0229 - u1530 set in bcm...
# 2  1hyksmrk6sz000990  approved 4.9(olh) for added diagnostics with t...
# 3  3hcfdfel3sh241701                         steering wheel replacement
# 4  1hrffhel1rz181474      replaced steering message no longer displayed
#
#                                    CUSTOMER_VERBATIM REPAIR_DATE  \
# 0                        steering wheel coming apart  01-02-2024
# 1         customer states heated steering wheel inop  01-03-2024
# 2  owner reports: the super cruise bar on the ste...  01-04-2024
# 3  customer states the lettering and finish on th...  01-04-2024
# 4  c/s: customer states the service driver assist...  01-05-2024
#
#                   CAUSAL_PART_NM             GLOBAL_LABOR_CODE_DESCRIPTION  \
# ...

# %%
# Identify numerical columns
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns

# Convert numerical columns to numeric type (this will turn invalid entries into NaN)
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')

# %%
print(df.isnull().sum())
# Out:
# VIN                              0
# TRANSACTION_ID                   0
# CORRECTION_VERBATIM              0
# CUSTOMER_VERBATIM                0
# REPAIR_DATE                      0
# CAUSAL_PART_NM                   0
# GLOBAL_LABOR_CODE_DESCRIPTION    0
# PLATFORM                         0
# BODY_STYLE                       0
# VPPC                             0
# PLANT                            0
# BUILD_COUNTRY                    0
# LAST_KNOWN_DLR_NAME              0
# LAST_KNOWN_DLR_CITY              0
# REPAIRING_DEALER_CODE            0
# DEALER_NAME                      0
# REPAIR_DLR_CITY                  0
# STATE                            0
# DEALER_REGION                    0
# REPAIR_DLR_POSTAL_CD             0
# REPAIR_AGE                       0
# KM                               0
# COMPLAINT_CD_CSI                 0
# COMPLAINT_CD                     0
# VEH_TEST_GRP                     0
# COUNTRY_SALE_ISO                 0
# ORD_SELLING_SRC_CD               0
# ...

# %%
#print numeric data
df[numeric_cols]
# Out:
#     TRANSACTION_ID  DEALER_REGION  REPAIR_AGE  COMPLAINT_CD_CSI  \
# 0            13021              1           6                 0
# 1            13028              1           5                 0
# 2            13035              1           9                 0
# 3            13021              1          10                 0
# 4            13021              1           0                 0
# ..             ...            ...         ...               ...
# 95           13041              1          32                 0
# 96           13048              1           8                 0
# 97           13044              1          12                 0
# 98           13045              1           4                 0
# 99           13041              1          38                 0
#
#     ORD_SELLING_SRC_CD  GLOBAL_LABOR_CODE  TRANSMISSION_SOURCE_PLANT  \
# 0                   13                130               2.878270e+05
# ...

# %%
# For numerical columns, fill with mean
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
for col in numeric_cols:
    df[col].fillna(df[col].mean(), inplace=True)

# For categorical columns, fill with mode
categorical_cols = df.select_dtypes(include=['object', 'category']).columns
for col in categorical_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6764\3573698451.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mean(), inplace=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6764\3573698451.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
print(df.isnull().sum())
# Out:
# VIN                              0
# TRANSACTION_ID                   0
# CORRECTION_VERBATIM              0
# CUSTOMER_VERBATIM                0
# REPAIR_DATE                      0
# CAUSAL_PART_NM                   0
# GLOBAL_LABOR_CODE_DESCRIPTION    0
# PLATFORM                         0
# BODY_STYLE                       0
# VPPC                             0
# PLANT                            0
# BUILD_COUNTRY                    0
# LAST_KNOWN_DLR_NAME              0
# LAST_KNOWN_DLR_CITY              0
# REPAIRING_DEALER_CODE            0
# DEALER_NAME                      0
# REPAIR_DLR_CITY                  0
# STATE                            0
# DEALER_REGION                    0
# REPAIR_DLR_POSTAL_CD             0
# REPAIR_AGE                       0
# KM                               0
# COMPLAINT_CD_CSI                 0
# COMPLAINT_CD                     0
# VEH_TEST_GRP                     0
# COUNTRY_SALE_ISO                 0
# ORD_SELLING_SRC_CD               0
# ...

# %%
# Display updated DataFrame structure
print(df.info())

# Display the first few rows of the cleaned DataFrame
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 51 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   VIN                            100 non-null    object
#  1   TRANSACTION_ID                 100 non-null    int64
#  2   CORRECTION_VERBATIM            100 non-null    object
#  3   CUSTOMER_VERBATIM              100 non-null    object
#  4   REPAIR_DATE                    100 non-null    object
#  5   CAUSAL_PART_NM                 100 non-null    object
#  6   GLOBAL_LABOR_CODE_DESCRIPTION  100 non-null    object
#  7   PLATFORM                       100 non-null    object
#  8   BODY_STYLE                     100 non-null    object
#  9   VPPC                           100 non-null    object
#  10  PLANT                          100 non-null    object
#  11  BUILD_COUNTRY                  100 non-null    object
# ...

# %%
#Identify numerical columns
numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns

# Plot box plots for each numerical column
for col in numeric_cols:
    plt.figure(figsize=(6, 3))
    sns.boxplot(x=df[col])
    plt.title(f'Box Plot of {col}')
    plt.xlabel(col)
    plt.show()

# %%
# Function to find outliers using IQR
def find_outliers(column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)][column]
    return outliers

# Identify outliers for each numerical column
outlier_dict = {}
for col in numeric_cols:
    outlier_dict[col] = find_outliers(col)

# Display the outliers
for col, outliers in outlier_dict.items():
    print(f"Outliers in {col}:")
    print(outliers, '\n')
# Out:
# Outliers in TRANSACTION_ID:
# 6     13071
# 9     13074
# 24    13073
# 59    13081
# 88    13065
# Name: TRANSACTION_ID, dtype: int64
#
# Outliers in DEALER_REGION:
# 16    4
# 33    4
# 79    4
# Name: DEALER_REGION, dtype: int64
#
# Outliers in REPAIR_AGE:
# 23    47
# 26    50
# 48    49
# 69    46
# Name: REPAIR_AGE, dtype: int64
#
# Outliers in COMPLAINT_CD_CSI:
# Series([], Name: COMPLAINT_CD_CSI, dtype: int64)
#
# Outliers in ORD_SELLING_SRC_CD:
# Series([], Name: ORD_SELLING_SRC_CD, dtype: int64)
#
# Outliers in GLOBAL_LABOR_CODE:
# 1     2400
# 5       20
# 8       50
# 14      50
# 15      20
# 19      20
# 21      50
# 23      50
# 26      50
# 36    2400
# 37    2400
# 40    2400
# 43      50
# 51      50
# 54      50
# 56    2400
# 65      50
# 66      20
# 67      50
# 74    2400
# 89      20
# 94      50
# Name: GLOBAL_LABOR_CODE, dtype: int64
#
# Outliers in TRANSMISSION_SOURCE_PLANT:
# 11    822972980.0
# 18    822972980.0
# 21    822972980.0
# 22    822972980.0
# ...

# %%
# Handling outliers using Interquartile Range (IQR) for numerical columns (excluding identifiers)
numeric_cols = ['REPAIR_AGE', 'GLOBAL_LABOR_CODE', 'TRANSMISSION_SOURCE_PLANT', 'SRC_VER_NBR', 'LAST_KNOWN_DELVRY_TYPE_CD', 'NON_CAUSAL_PART_QTY', 'SALES_REGION_CODE']

for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]

# Display information after handling outliers
print("\nNumerical columns after handling outliers:")
print(df[numeric_cols].describe())
# Out:
# Numerical columns after handling outliers:
#        REPAIR_AGE  GLOBAL_LABOR_CODE  TRANSMISSION_SOURCE_PLANT  SRC_VER_NBR  \
# count    47.00000               47.0               4.700000e+01    47.000000
# mean     12.12766              130.0               3.624708e+07     5.319149
# std      10.05121                0.0               6.614071e+07     1.461184
# min       0.00000              130.0               2.878270e+05     4.000000
# 25%       4.00000              130.0               2.878270e+05     4.000000
# 50%       9.00000              130.0               8.042172e+06     6.000000
# 75%      17.50000              130.0               1.774929e+07     6.000000
# max      39.00000              130.0               2.493000e+08     8.000000
#
#        LAST_KNOWN_DELVRY_TYPE_CD  NON_CAUSAL_PART_QTY  SALES_REGION_CODE
# count                  47.000000                 47.0               47.0
# mean                   13.127660                  0.0                1.0
# ...

# %%
#Display the statistical summary of numerical columns
print("\nStatistical summary of numerical columns after handling outliers:")
df[numeric_cols].describe()
#Statistical Summary: This will give you the count, mean, standard deviation, minimum, and maximum values, allowing you to confirm that the data now falls within a reasonable range
# Out:
# Statistical summary of numerical columns after handling outliers:
#        REPAIR_AGE  GLOBAL_LABOR_CODE  TRANSMISSION_SOURCE_PLANT  SRC_VER_NBR  \
# count    47.00000               47.0               4.700000e+01    47.000000
# mean     12.12766              130.0               3.624708e+07     5.319149
# std      10.05121                0.0               6.614071e+07     1.461184
# min       0.00000              130.0               2.878270e+05     4.000000
# 25%       4.00000              130.0               2.878270e+05     4.000000
# 50%       9.00000              130.0               8.042172e+06     6.000000
# 75%      17.50000              130.0               1.774929e+07     6.000000
# max      39.00000              130.0               2.493000e+08     8.000000
#
#        LAST_KNOWN_DELVRY_TYPE_CD  NON_CAUSAL_PART_QTY  SALES_REGION_CODE
# count                  47.000000                 47.0               47.0
# ...

# %% [markdown]
# ### Identifying Critical Columns:

# %%
# Define the top 5 critical columns
critical_columns = ['TRANSACTION_ID', 'REPAIR_DATE', 'TOTALCOST', 'KM', 'ENGINE']

# Reasoning for selection
reasoning = {
    'TRANSACTION_ID': 'Unique identifier for each transaction, crucial for tracking individual records and ensuring data integrity.',
    'REPAIR_DATE': 'The date of repair is important for time-based analysis. Stakeholders can use this data to identify trends, seasonality, and the effectiveness of maintenance schedules.',
    'TOTALCOST': 'The total cost of repair is essential for financial analysis. Stakeholders can use this information to monitor repair expenses, budget allocation, and identify cost-saving opportunities.',
    'KM': 'This column represents the kilometers driven, a critical indicator of vehicle usage. Stakeholders can analyze this data to assess wear and tear, predict maintenance needs, and evaluate vehicle performance over time.',
    'ENGINE': 'The type of engine provides insights into the technical aspects of the vehicle. Stakeholders can use this data to segment vehicles by engine type, analyze engine-related issues, and improve engineering designs or maintenance protocols.'
}

# %%
reasoning
# Out:
# {'TRANSACTION_ID': 'Unique identifier for each transaction, crucial for tracking individual records and ensuring data integrity.',
#  'REPAIR_DATE': 'The date of repair is important for time-based analysis. Stakeholders can use this data to identify trends, seasonality, and the effectiveness of maintenance schedules.',
#  'TOTALCOST': 'The total cost of repair is essential for financial analysis. Stakeholders can use this information to monitor repair expenses, budget allocation, and identify cost-saving opportunities.',
#  'KM': 'This column represents the kilometers driven, a critical indicator of vehicle usage. Stakeholders can analyze this data to assess wear and tear, predict maintenance needs, and evaluate vehicle performance over time.',
# ...

# %%
# Display the critical columns and reasoning
print("Top 5 Critical Columns and Their Reasoning:")
for col in critical_columns:
    print(f"\nColumn: {col}")
    print(f"Reasoning: {reasoning[col]}")
# Out:
# Top 5 Critical Columns and Their Reasoning:
#
# Column: TRANSACTION_ID
# Reasoning: Unique identifier for each transaction, crucial for tracking individual records and ensuring data integrity.
#
# Column: REPAIR_DATE
# Reasoning: The date of repair is important for time-based analysis. Stakeholders can use this data to identify trends, seasonality, and the effectiveness of maintenance schedules.
#
# Column: TOTALCOST
# Reasoning: The total cost of repair is essential for financial analysis. Stakeholders can use this information to monitor repair expenses, budget allocation, and identify cost-saving opportunities.
#
# Column: KM
# Reasoning: This column represents the kilometers driven, a critical indicator of vehicle usage. Stakeholders can analyze this data to assess wear and tear, predict maintenance needs, and evaluate vehicle performance over time.
#
# Column: ENGINE
# ...

# %%
 # Define the top 5 critical columns
critical_columns = ['VIN', 'REPAIR_DATE', 'CUSTOMER_VERBATIM', 'CAUSAL_PART_NM', 'TOTALCOST']

# Reasoning for selection
reasoning = {
    'VIN': 'This unique identifier is essential for tracking individual vehicles. It helps in linking repairs and issues to specific vehicles, enabling stakeholders to identify patterns or recurring problems. This can aid in understanding the reliability and maintenance needs of different vehicle models.',
    'REPAIR_DATE': 'The date of repair allows for time-based analysis. Understanding trends over time can help stakeholders identify seasonal issues, periods of higher maintenance demand, and evaluate the effectiveness of maintenance schedules. This is crucial for managing repair shop workloads and forecasting future service demands.',
    'CUSTOMER_VERBATIM': 'This column contains the customer\'s description of the problem. Analyzing common phrases or complaints provides valuable insights into the most frequent issues experienced by customers. This information can inform service improvements and strategies to enhance customer satisfaction.',
    'CAUSAL_PART_NM': 'This column identifies the part that caused the issue. Understanding which parts are most frequently problematic can guide quality improvement initiatives and inventory management. It helps stakeholders prioritize quality improvements and ensure that frequently needed parts are readily available.',
    'TOTALCOST': 'The total cost of repair is crucial for financial analysis. Stakeholders can use this information to monitor repair expenses, identify cost-saving opportunities, and allocate budgets more effectively. It helps assess the financial impact of different types of repairs and make informed decisions about maintenance strategies.'
}

# Displaying the critical columns and their reasoning
for column in critical_columns:
    print(f"Column: {column}")
    print(f"Reasoning: {reasoning[column]}")
    print("\n")
# Out:
# Column: VIN
# Reasoning: This unique identifier is essential for tracking individual vehicles. It helps in linking repairs and issues to specific vehicles, enabling stakeholders to identify patterns or recurring problems. This can aid in understanding the reliability and maintenance needs of different vehicle models.
#
#
# Column: REPAIR_DATE
# Reasoning: The date of repair allows for time-based analysis. Understanding trends over time can help stakeholders identify seasonal issues, periods of higher maintenance demand, and evaluate the effectiveness of maintenance schedules. This is crucial for managing repair shop workloads and forecasting future service demands.
#
#
# Column: CUSTOMER_VERBATIM
# ...

# %% [markdown]
# ## Visualization 1: Frequency of Repairs by Month (REPAIR_DATE)

# %%
# Convert REPAIR_DATE to datetime and extract month-year
df['REPAIR_DATE'] = pd.to_datetime(df['REPAIR_DATE'])
df['Repair_Month'] = df['REPAIR_DATE'].dt.to_period('M')

# Plot frequency of repairs by month
repair_counts = df['Repair_Month'].value_counts().sort_index()

plt.figure(figsize=(7, 3))
repair_counts.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Frequency of Repairs by Month', fontsize=18, fontweight='bold')
plt.xlabel('Month', fontsize=14, color='blue')
plt.ylabel('Number of Repairs', fontsize=14, color='blue')
plt.xticks(rotation=45, color='blue')
plt.yticks(color='blue')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ## Visualization 2: Top 10 Most Frequent Customer Complaints (CUSTOMER_VERBATIM)

# %%
from collections import Counter

# Split and count words in CUSTOMER_VERBATIM
complaints = df['CUSTOMER_VERBATIM'].str.lower().str.split()
complaint_words = Counter([word for complaint in complaints.dropna() for word in complaint if len(word) > 3])
top_complaints = complaint_words.most_common(10)

# Plot top 10 most frequent customer complaints
words, counts = zip(*top_complaints)
plt.figure(figsize=(7, 3))
plt.bar(words, counts, color='lightgreen', edgecolor='black')
plt.title('Top 10 Most Frequent Customer Complaints', fontsize=18, fontweight='bold')
plt.xlabel('Words', fontsize=14, color='green')
plt.ylabel('Frequency', fontsize=14, color='green')
plt.xticks(rotation=45, color='green')
plt.yticks(color='green')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ## VVisualization 3: Top 10 Most Problematic Parts (CAUSAL_PART_NM)

# %%
# Plot top 10 most problematic parts
part_counts = df['CAUSAL_PART_NM'].value_counts().head(10)

plt.figure(figsize=(7, 3))
part_counts.plot(kind='bar', color='salmon', edgecolor='black')
plt.title('Top 10 Most Problematic Parts', fontsize=18, fontweight='bold')
plt.xlabel('Part Name', fontsize=14)
plt.ylabel('Number of Occurrences', fontsize=14)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Plot donut chart for top 10 most problematic parts
part_counts = df['CAUSAL_PART_NM'].value_counts().head(10)

plt.figure(figsize=(6, 6))
plt.pie(part_counts, labels=part_counts.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired(range(len(part_counts))))
centre_circle = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title('Top 10 Most Problematic Parts', fontsize=18, fontweight='bold')
plt.show()

# %% [markdown]
# ## Generating tags/features from free text available :

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from collections import Counter
import string

# Download NLTK stop words if not already downloaded
nltk.download('stopwords')
nltk.download('punkt')

# Preprocess the text data
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()
    # Remove punctuation and special characters
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Tokenize the text
    tokens = word_tokenize(text)
    # Remove stop words
    tokens = [word for word in tokens if word not in stopwords.words('english')]
    return tokens

# Apply preprocessing to the CUSTOMER_VERBATIM column
df['CLEANED_VERBATIM'] = df['CUSTOMER_VERBATIM'].apply(lambda x: preprocess_text(str(x)))

# Extract key phrases and generate tags
all_words = [word for tokens in df['CLEANED_VERBATIM'] for word in tokens]
word_counts = Counter(all_words)

# Generate tags based on the most common key phrases
top_tags = word_counts.most_common(20)
print("Top Tags:")
for tag, count in top_tags:
    print(f"{tag}: {count}")

# Add tags to the dataframe
df['TAGS'] = df['CLEANED_VERBATIM'].apply(lambda x: ' '.join([word for word in x if word in dict(top_tags)]))

# Display the dataframe with tags
print(df[['CUSTOMER_VERBATIM', 'TAGS']].head())
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Top Tags:
# steering: 49
# wheel: 49
# states: 28
# customer: 25
# coming: 18
# cs: 10
# heated: 10
# apart: 8
# ro: 7
# sop: 7
# cust: 7
# advise: 6
# side: 6
# stitching: 6
# bottom: 6
# check: 5
# pra: 5
# trim: 5
# install: 5
# loose: 5
#                                    CUSTOMER_VERBATIM  \
# 0                        steering wheel coming apart
# 2  owner reports: the super cruise bar on the ste...
# 3  customer states the lettering and finish on th...
# 4  c/s: customer states the service driver assist...
# 7  special order part [ steering wheel heated ste...
#
#                                      TAGS
# 0             steering wheel coming apart
# ...

# %%
df.head(62)
# Out:
#                   VIN  TRANSACTION_ID  \
# 0   3hcfdde89sh220903           13021
# 2   1hyksmrk6sz000990           13035
# 3   3hcfdfel3sh241701           13021
# 4   1hrffhel1rz181474           13021
# 7   3hcfdfed4sh352945           13021
# 10  1hcfdhe86sz274242           13023
# 12  1hyksmrk4sz001121           13025
# 17  1h1fz6s00n4109597           13025
# 20  3hrffcer3nh528824           13025
# 24  1hks2jkr2nr336997           13073
# 25  1hcfdeed3sz308171           13037
# 28  1hcfyeed6nz182017           13040
# 29  1hcfdeed5sz117691           13025
# 31  1hr49se7xrf103023           13026
# 32  3hrffee82rh175165           13029
# 35  1hr49rey4sf251024           13029
# 38  1hks2jkl9mr285352           13030
# 39  1hnskrkd0rr120386           13030
# 41  1hrs9eed3mz313803           13035
# 44  1hr19sey5rf265525           13054
# 46  1hcfdeed0nz543303           13030
# 47  1hcryded2nz208869           13037
# 50  1h1jd5sb0l4142407           13039
# ...

# %% [markdown]
# ## Highlight discrepancies in the dataset (e.g., null values, missing primary keys)

# %%
df.columns = df.columns.to_list()
df.columns
# Out:
# Index(['VIN', 'TRANSACTION_ID', 'CORRECTION_VERBATIM', 'CUSTOMER_VERBATIM',
#        'REPAIR_DATE', 'CAUSAL_PART_NM', 'GLOBAL_LABOR_CODE_DESCRIPTION',
#        'PLATFORM', 'BODY_STYLE', 'VPPC', 'PLANT', 'BUILD_COUNTRY',
#        'LAST_KNOWN_DLR_NAME', 'LAST_KNOWN_DLR_CITY', 'REPAIRING_DEALER_CODE',
#        'DEALER_NAME', 'REPAIR_DLR_CITY', 'STATE', 'DEALER_REGION',
#        'REPAIR_DLR_POSTAL_CD', 'REPAIR_AGE', 'KM', 'COMPLAINT_CD_CSI',
#        'COMPLAINT_CD', 'VEH_TEST_GRP', 'COUNTRY_SALE_ISO',
#        'ORD_SELLING_SRC_CD', 'OPTN_FAMLY_CERTIFICATION',
#        'OPTF_FAMLY_EMISSIOF_SYSTEM', 'GLOBAL_LABOR_CODE',
#        'TRANSACTION_CATEGORY', 'REPORTING_COST', 'TOTALCOST', 'LBRCOST',
#        'ENGINE', 'ENGINE_DESC', 'TRANSMISSION', 'TRANSMISSION_DESC',
#        'ENGINE_SOURCE_PLANT', 'ENGINE_TRACE_NBR', 'TRANSMISSION_SOURCE_PLANT',
#        'TRANSMISSION_TRACE_NBR', 'SRC_TXN_ID', 'SRC_VER_NBR',
#        'TRANSACTION_CNTR', 'MEDIA_FLAG', 'VIN_MODL_DESGTR', 'LINE_SERIES',
# ...

# %%
totalcost = df['TOTALCOST']
totalcost
# Out:
# 0       370.03
# 2     3,205.45
# 3       445.28
# 4     1,439.65
# 7       427.08
# 10    1,006.10
# 12    1,414.83
# 17      457.47
# 20      621.34
# 24      454.63
# 25      456.98
# 28      299.77
# 29      432.68
# 31      487.54
# 32      511.39
# 35      521.02
# 38      519.97
# 39      411.41
# 41      445.12
# 44      457.98
# 46         514
# 47      127.98
# 50      412.41
# 52      143.68
# 53      963.92
# 58      603.59
# 60      513.95
# 62      687.11
# 63    1,335.14
# 64      474.01
# 68      535.75
# 70      608.01
# 71      365.36
# 72      551.25
# 73      475.85
# 75      622.24
# 78      319.43
# 80      512.28
# 81      388.02
# 82    1,268.82
# 83    1,480.02
# 85      430.11
# 86      507.32
# 87      435.26
# 92      256.11
# 96    1,474.06
# 98      101.85
# Name: TOTALCOST, dtype: object

# %%
import re
# Function to clean and convert the 'TOTALCOST' column
import re
def clean_totalcost(value):
    # Remove any non-numeric characters except for the decimal point
    value = re.sub(r'[^\d.]', '', str(value))
    try:
        return float(value)
    except ValueError:
        return None

# Apply the cleaning function to the 'TOTALCOST' column
df['TOTALCOST'] = df['TOTALCOST'].apply(clean_totalcost)

# Check for null values in the 'TOTALCOST' column and handle them
df['TOTALCOST'].fillna(df['TOTALCOST'].mean(), inplace=True)

# Dropping rows with missing values in critical columns like 'CAUSAL_PART_NM' and 'VIN'
df.dropna(subset=['CAUSAL_PART_NM', 'VIN'], inplace=True)

print(df.head())  # Display the first few rows to verify the changes
# Out:
#                  VIN  TRANSACTION_ID  \
# 0  3hcfdde89sh220903           13021
# 2  1hyksmrk6sz000990           13035
# 3  3hcfdfel3sh241701           13021
# 4  1hrffhel1rz181474           13021
# 7  3hcfdfed4sh352945           13021
#
#                                  CORRECTION_VERBATIM  \
# 0                   replaced steering wheel now okay
# 2  approved 4.9(olh) for added diagnostics with t...
# 3                         steering wheel replacement
# 4      replaced steering message no longer displayed
# 7                            replaced steering wheel
#
#                                    CUSTOMER_VERBATIM REPAIR_DATE  \
# 0                        steering wheel coming apart  2024-01-02
# 2  owner reports: the super cruise bar on the ste...  2024-01-04
# 3  customer states the lettering and finish on th...  2024-01-04
# 4  c/s: customer states the service driver assist...  2024-01-05
# 7  special order part [ steering wheel heated ste...  2024-01-05
#
# ...

# %% [markdown]
# Cleaning the TOTALCOST Column: We define a function clean_totalcost that removes any non-numeric characters from the values in the TOTALCOST column. The function then tries to convert the cleaned value to a float. If the conversion fails, it returns None.
#
# Applying the Cleaning Function: We apply the clean_totalcost function to the TOTALCOST column to clean and convert the values.
#
# Handling Null Values: We replace any remaining null values in the TOTALCOST column with the mean value of the column.
#
# Dropping Rows with Missing Values in Critical Columns: We drop rows with missing values in critical columns like CAUSAL_PART_NM and VIN to maintain data integrity.

# %%
#Check for null values in the dataset
null_values = df.isnull().sum()
print("Null Values in Each Column:")
print(null_values)
# Out:
# Null Values in Each Column:
# VIN                              0
# TRANSACTION_ID                   0
# CORRECTION_VERBATIM              0
# CUSTOMER_VERBATIM                0
# REPAIR_DATE                      0
# CAUSAL_PART_NM                   0
# GLOBAL_LABOR_CODE_DESCRIPTION    0
# PLATFORM                         0
# BODY_STYLE                       0
# VPPC                             0
# PLANT                            0
# BUILD_COUNTRY                    0
# LAST_KNOWN_DLR_NAME              0
# LAST_KNOWN_DLR_CITY              0
# REPAIRING_DEALER_CODE            0
# DEALER_NAME                      0
# REPAIR_DLR_CITY                  0
# STATE                            0
# DEALER_REGION                    0
# REPAIR_DLR_POSTAL_CD             0
# REPAIR_AGE                       0
# KM                               0
# COMPLAINT_CD_CSI                 0
# COMPLAINT_CD                     0
# VEH_TEST_GRP                     0
# COUNTRY_SALE_ISO                 0
# ...

# %% [markdown]
# ## there are no null values in  dataset,

# %%
 #Check the data type of the 'TOTALCOST' column
print("Data Type of TOTALCOST Column:")
print(df['TOTALCOST'].dtype)
# Out:
# Data Type of TOTALCOST Column:
# float64

# %%
# Identify non-numeric values in the 'TOTALCOST' column
non_numeric_values = df['TOTALCOST'][df['TOTALCOST'].apply(lambda x: not str(x).replace('.', '', 1).isdigit())]
print("Non-Numeric Values in TOTALCOST Column:")
print(non_numeric_values)
# Out:
# Non-Numeric Values in TOTALCOST Column:
# Series([], Name: TOTALCOST, dtype: float64)

# %% [markdown]
# ## The TOTALCOST column is already in the correct numeric format (float64), and there are no non-numeric values.

# %%
 #Summary statistics to identify potential outliers in 'TOTALCOST'
print("Summary Statistics for TOTALCOST Column:")
print(df['TOTALCOST'].describe())

# Visualize distribution of 'TOTALCOST' to identify outliers
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.boxplot(df['TOTALCOST'].dropna())
plt.title('Boxplot of TOTALCOST')
plt.ylabel('TOTALCOST')
plt.show()
# Out:
# Summary Statistics for TOTALCOST Column:
# count      47.000000
# mean      648.792553
# std       519.477672
# min       101.850000
# 25%       428.595000
# 50%       487.540000
# 75%       614.675000
# max      3205.450000
# Name: TOTALCOST, dtype: float64

# %% [markdown]
# ## Observation: The maximum value (3205.45) is significantly higher than the 75th percentile (614.68), indicating potential outliers in the dataset

# %%
###using the Interquartile Range (IQR) method to filter out these outliers and ensure a more accurate analysis.
Q1 = df['TOTALCOST'].quantile(0.25)
Q3 = df['TOTALCOST'].quantile(0.75)
IQR = Q3 - Q1

# Filtering out the outliers
df_cleaned = df[~((df['TOTALCOST'] < (Q1 - 1.5 * IQR)) | (df['TOTALCOST'] > (Q3 + 1.5 * IQR)))]

# Summary statistics after removing outliers
print("Summary Statistics for TOTALCOST Column After Removing Outliers:")
print(df_cleaned['TOTALCOST'].describe())
# Out:
# Summary Statistics for TOTALCOST Column After Removing Outliers:
# count     35.000000
# mean     472.335714
# std       93.123239
# min      256.110000
# 25%      428.595000
# 50%      457.980000
# 75%      516.985000
# max      687.110000
# Name: TOTALCOST, dtype: float64

# %% [markdown]
# ## preprocess the text data to clean and tokenize it, making it easier to analyze and generate meaningful tags

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string

nltk.download('stopwords')
nltk.download('punkt')

# Preprocess the text data
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()
    # Remove punctuation and special characters
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Tokenize the text
    tokens = word_tokenize(text)
    # Remove stop words
    tokens = [word for word in tokens if word not in stopwords.words('english')]
    return tokens

# Apply preprocessing to the CUSTOMER_VERBATIM column
df['CLEANED_VERBATIM'] = df['CUSTOMER_VERBATIM'].apply(lambda x: preprocess_text(str(x)))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df['CLEANED_VERBATIM']
# Out:
# 0                      [steering, wheel, coming, apart]
# 2     [owner, reports, super, cruise, bar, steering,...
# 3     [customer, states, lettering, finish, steering...
# 4     [cs, customer, states, service, driver, assist...
# 7     [special, order, part, steering, wheel, heated...
# 10    [cs, removed, steering, wheel, gain, access, b...
# 12    [install, special, order, part, customer, stat...
# 17    [heated, steering, wheel, inop, hit, button, t...
# 20    [customer, states, stitching, steering, wheel,...
# 24    [customer, states, steering, wheels, stiching,...
# 25    [wrap, steeering, wheel, peeling, need, pra, d...
# 28    [trim, moulding, diagnosis, trim, moulding, di...
# 29    [install, sop, customer, states, stitching, st...
# 31    [cust, states, steering, wheel, materuial, del...
# 32    [customer, states, steering, wheel, heat, butt...
# 35    [cs, cust, states, leater, bottom, steering, w...
# 38    [customer, states, steering, wheel, cover, com...
# ...

# %%
#the CUSTOMER_VERBATIM column has been successfully preprocessed and tokenized. Each entry in the CLEANED_VERBATIM column is now a list of words, with punctuation removed and stop words filtered out.

# %% [markdown]
# ##the CUSTOMER_VERBATIM column has been successfully preprocessed and tokenized. Each entry in the CLEANED_VERBATIM column is now a list of words, with punctuation removed and stop words filtered out.

# %%
print(df['CUSTOMER_VERBATIM'].head(60))
# Out:
# 0                           steering wheel coming apart
# 2     owner reports: the super cruise bar on the ste...
# 3     customer states the lettering and finish on th...
# 4     c/s: customer states the service driver assist...
# 7     special order part [ steering wheel heated ste...
# 10    c/s: removed steering wheel to gain access to ...
# 12    (install special order part) customer states t...
# 17    heated steering wheel inop. when you hit the b...
# 20    customer states stitching on steering wheel is...
# 24    customer states steering wheels stiching comin...
# 25    wrap on the steeering wheel is peeling ***need...
# 28    trim or moulding diagnosis trim or moulding di...
# 29    install sop. customer states stitching on stee...
# 31    cust states steering wheel materuial delaminat...
# 32    customer states steering wheel does not heat, ...
# 35    c/s: cust states leater at the bottom of the s...
# 38    customer states that the steering wheel cover ...
# ...

# %%
df.head(4)
# Out:
#                  VIN  TRANSACTION_ID  \
# 0  3hcfdde89sh220903           13021
# 2  1hyksmrk6sz000990           13035
# 3  3hcfdfel3sh241701           13021
# 4  1hrffhel1rz181474           13021
#
#                                  CORRECTION_VERBATIM  \
# 0                   replaced steering wheel now okay
# 2  approved 4.9(olh) for added diagnostics with t...
# 3                         steering wheel replacement
# 4      replaced steering message no longer displayed
#
#                                    CUSTOMER_VERBATIM REPAIR_DATE  \
# 0                        steering wheel coming apart  2024-01-02
# 2  owner reports: the super cruise bar on the ste...  2024-01-04
# 3  customer states the lettering and finish on th...  2024-01-04
# 4  c/s: customer states the service driver assist...  2024-01-05
#
#                   CAUSAL_PART_NM GLOBAL_LABOR_CODE_DESCRIPTION  \
# 0      wheel asm-strg *jet black    steering wheel replacement
# ...

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string

# Download necessary NLTK resources
nltk.download('stopwords')
nltk.download('punkt')

# Preprocess the text data
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()
    # Remove punctuation and special characters
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Tokenize the text
    tokens = word_tokenize(text)
    # Remove stop words
    tokens = [word for word in tokens if word not in stopwords.words('english')]
    # Join tokens back into a single string
    clean_text = ' '.join(tokens)
    return clean_text

# Apply preprocessing to the CUSTOMER_VERBATIM column
df['CLEANED_VERBATIM'] = df['CUSTOMER_VERBATIM'].apply(lambda x: preprocess_text(str(x)))

# Display the cleaned and tokenized column
print(df['CLEANED_VERBATIM'].head(60)) 

#the CUSTOMER_VERBATIM column has been successfully preprocessed and tokenized. Each entry in the CLEANED_VERBATIM column is now a list of words, with punctuation removed and stop words filtered out.
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 0                           steering wheel coming apart
# 2     owner reports super cruise bar steering wheel ...
# 3     customer states lettering finish steering whee...
# 4     cs customer states service driver assist syste...
# 7     special order part steering wheel heated steer...
# 10    cs removed steering wheel gain access back sid...
# 12    install special order part customer states rig...
# 17    heated steering wheel inop hit button turns im...
# 20    customer states stitching steering wheel comin...
# 24    customer states steering wheels stiching comin...
# 25    wrap steeering wheel peeling need pra done man...
# ...

# %%
# before cleaning 
df['CUSTOMER_VERBATIM'].head(3)
# Out:
# 0                     [steering, wheel, coming, apart]
# 2    [owner, reports, super, cruise, bar, steering,...
# 3    [customer, states, lettering, finish, steering...
# Name: CUSTOMER_VERBATIM, dtype: object

# %%
df.head(2)
# Out:
#                  VIN  TRANSACTION_ID  \
# 0  3hcfdde89sh220903           13021
# 2  1hyksmrk6sz000990           13035
#
#                                  CORRECTION_VERBATIM  \
# 0                   replaced steering wheel now okay
# 2  approved 4.9(olh) for added diagnostics with t...
#
#                                    CUSTOMER_VERBATIM REPAIR_DATE  \
# 0                   [steering, wheel, coming, apart]  2024-01-02
# 2  [owner, reports, super, cruise, bar, steering,...  2024-01-04
#
#                   CAUSAL_PART_NM GLOBAL_LABOR_CODE_DESCRIPTION  \
# 0      wheel asm-strg *jet black    steering wheel replacement
# 2  wheel asm-strg *backen blackk    steering wheel replacement
#
#            PLATFORM      BODY_STYLE       VPPC  ... TRANSACTION_CNTR  \
# 0  full-size trucks        crew cab      t1ccf  ...                1
# 2               bev  4 door utility  l233-lsop  ...                1
#
#   MEDIA_FLAG VIN_MODL_DESGTR LINE_SERIES LAST_KNOWN_DELVRY_TYPE_CD  \
# ...

# %%
df['TAGS'].head(15)
# Out:
# 0                                   wheel apart
# 2                owner reports cruise bar wheel
# 3            customer states finish wheel plant
# 4             cs customer states service driver
# 7                special order part wheel wheel
# 10                    cs wheel gain access back
# 12           special order part customer states
# 17          wheel inop button turns immediately
# 20              customer states wheel undone ri
# 24                 customer states wheels apart
# 25                   wrap wheel need management
# 28             trim diagnosis trim diagnosis cs
# 29          install customer states wheel apart
# 31    cust states materuial delamination bottom
# 32            customer states wheel heat button
# Name: TAGS, dtype: object

# %%
df.head(5)
# Out:
#                  VIN  TRANSACTION_ID  \
# 0  3hcfdde89sh220903           13021
# 2  1hyksmrk6sz000990           13035
# 3  3hcfdfel3sh241701           13021
# 4  1hrffhel1rz181474           13021
# 7  3hcfdfed4sh352945           13021
#
#                                  CORRECTION_VERBATIM  \
# 0                   replaced steering wheel now okay
# 2  approved 4.9(olh) for added diagnostics with t...
# 3                         steering wheel replacement
# 4      replaced steering message no longer displayed
# 7                            replaced steering wheel
#
#                                    CUSTOMER_VERBATIM REPAIR_DATE  \
# 0                   [steering, wheel, coming, apart]  2024-01-02
# 2  [owner, reports, super, cruise, bar, steering,...  2024-01-04
# 3  [customer, states, lettering, finish, steering...  2024-01-04
# 4  [cs, customer, states, service, driver, assist...  2024-01-05
# 7  [special, order, part, steering, wheel, heated...  2024-01-05
#
# ...

# %%
# Export the cleaned and tagged records to CSV
df.to_csv('cleaned_and_tagged_records.csv', index=False)

# %%
import os

# Print the current working directory
print(os.getcwd())
# Out:
# C:\Users\Admin
